# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df=pd.read_csv("adult_eda.csv")

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
bool_series = df.duplicated() # Dataset have any Duplicate(data setinde tekrar eden var mi?)
bool_series.value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
df.drop_duplicates(keep='first',inplace=True) #tekrar bak sayi uyusmuyor  inplace=True

# %%
df.shape
# Out:
# (32537, 15)

# %%
df.count()
# Out:
# age               32537
# workclass         32537
# fnlwgt            32537
# education         32537
# education-num     31735
# marital-status    32537
# occupation        32537
# relationship      27473
# race              32537
# sex               32537
# capital-gain      32537
# capital-loss      32537
# hours-per-week    32537
# native-country    32537
# salary            32537
# dtype: int64

# %%
df.shape
# Out:
# (32537, 15)

# %%
df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %%
df.rename(columns = {"education-num":"education_num", 'marital-status':'marital_status','capital-gain' :'capital_gain', 'hours-per-week': 'hours_per_week', 'native-country' : 'native_country','sex':'gender','capital-loss':'capital_loss'}, inplace = True)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
df.isna().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# gender               0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
df. isnull(). sum() * 100 / len(df)
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# gender            0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# #2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race  gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
#count=df.count()
#unique=df.nunique()
#freq=df.value_counts()
#top=freq.index[0]

# %%
df.select_dtypes(include=['object']).describe().T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# gender          32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %%
object_col=df[['workclass', 'education', 'marital_status', 'occupation', 'relationship', 'race', 'gender', 'native_country', 'salary']]

# %%
#object_col=df.columns[df.dytpes==object]

# %%
list(object_col)
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'gender',
#  'native_country',
#  'salary']

# %%
object_col
# Out:
#               workclass   education      marital_status         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race  gender native_country salary
# 0      Not-in-family  White    Male  United-States  <=50K
# 1            Husband  White    Male  United-States  <=50K
# 2      Not-in-family  White    Male  United-States  <=50K
# 3            Husband  Black    Male  United-States  <=50K
# 4               Wife  Black  Female           Cuba  <=50K
# ...              ...    ...     ...            ...    ...
# 32556           Wife  White  Female  United-States  <=50K
# 32557        Husband  White    Male  United-States   >50K
# 32558      Unmarried  White  Female  United-States  <=50K
# 32559            NaN  White    Male  United-States  <=50K
# 32560           Wife  White  Female  United-States   >50K
#
# [32537 rows x 9 columns]

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64
# ----------------------------------------
# occupation
# ----------------
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64
# ----------------------------------------
# relationship
# ----------------
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64
# ----------------------------------------
# race
# ----------------
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64
# ----------------------------------------
# gender
# ----------------
# Male      21775
# Female    10762
# Name: gender, dtype: int64
# ----------------------------------------
# native_country
# ----------------
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64
# ----------------------------------------
# salary
# ----------------
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64
# ----------------------------------------

# %% [markdown]
# **Check if the Dataset has any Question Mark** **``"?"``**

# %%
df.select_dtypes(include=['object']).apply(lambda x: x.str.contains('\?')).any()
# Out:
# workclass          True
# education         False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# gender            False
# native_country     True
# salary            False
# dtype: bool

# %%
df.isin(['?']).any()#
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# gender            False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %%
object_col.salary.value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots()

object_col.salary.value_counts().plot.bar() 
ax.set_xlabel("Salary") 
ax.bar_label(ax.containers[0],label_type="edge") ;
#for i in ax.containers :
    #ax.bar_label(i)

# %%
object_col.salary.value_counts()/len(df)
# Out:
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
myexplode=[0,0.2]
mycolors = ["LightBlue",  "gold"]

labels=object_col.salary.value_counts().index
sizes=object_col.salary.value_counts()

plt.figure(figsize = (12,10))

plt.pie(sizes,labels=labels, 
        explode=myexplode, 
        autopct="%.1f%%",
        shadow=True,
        colors=mycolors) ;
plt.title("Percentage of Income-Levels", fontsize=16);

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# # age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
object_col.head()
# Out:
#           workclass  education      marital_status         occupation  \
# 0         State-gov  Bachelors       Never-married       Adm-clerical
# 1  Self-emp-not-inc  Bachelors  Married-civ-spouse    Exec-managerial
# 2           Private    HS-grad            Divorced  Handlers-cleaners
# 3           Private       11th  Married-civ-spouse  Handlers-cleaners
# 4           Private  Bachelors  Married-civ-spouse     Prof-specialty
#
#     relationship   race  gender native_country salary
# 0  Not-in-family  White    Male  United-States  <=50K
# 1        Husband  White    Male  United-States  <=50K
# 2  Not-in-family  White    Male  United-States  <=50K
# 3        Husband  Black    Male  United-States  <=50K
# 4           Wife  Black  Female           Cuba  <=50K

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race  gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.age.value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    876
# 33    875
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: age, Length: 73, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,6))

sns.boxplot(data=df, x='age') 
plt.show()

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
fig, ax = plt.subplots(figsize=(12,6))

sns.histplot(x = "age", data = df,bins=20, kde = True) ;

# %% [markdown]
# **Check the statistical values**

# %%
df.age.describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
fig , ax=plt.subplots(figsize=(12,6))

sns.boxplot(data=df, x='salary' ,y='age') 
plt.show()

# %%
fig , ax=plt.subplots(figsize=(12,6))
sns.set(style='whitegrid')

sns.histplot(data=df,x='age',bins=20,hue='salary',kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(data=df,x='age',hue='salary',color='red', shade=True) ;

# %% [markdown]
# Check the statistical values by "salary" levels

# %%
df.groupby("salary").age.describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# ## fnlwgt

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
sns.boxplot(x="fnlwgt",data=df) ;

# %%
sns.kdeplot(data=df,x="fnlwgt",shade=True)
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Density'>

# %% [markdown]
# **Check the statistical values**

# %%
df.fnlwgt.describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
sns.boxplot(data=df, x="salary",y="fnlwgt") 
plt.show()

# %%
sns.kdeplot(data=df, x="fnlwgt",hue="salary",shade=True)
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Density'>

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df.groupby("salary").fnlwgt.describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# ## capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
sns.boxplot(data=df,x='capital_gain')
# Out:
# <AxesSubplot:xlabel='capital_gain'>

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
sns.kdeplot(data=df, x="capital_gain",shade=True)
# Out:
# <AxesSubplot:xlabel='capital_gain', ylabel='Density'>

# %% [markdown]
# **Check the statistical values**

# %%
df.capital_gain.describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
sns.boxplot(data=df,x="salary",y="capital_gain") ;

# %%
sns.kdeplot(data=df,x="capital_gain",hue="salary") ;

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df.groupby("salary").capital_gain.describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %%
df[df.capital_gain>0].groupby("salary").capital_gain.describe()
#df.groupby("salary").capital_gain.describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ...........................

# %% [markdown]
# ## capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
sns.boxplot(x="capital_loss",data=df) ;

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
sns.kdeplot(x="capital_loss",data=df,shade=True)
# Out:
# <AxesSubplot:xlabel='capital_loss', ylabel='Density'>

# %% [markdown]
# **Check the statistical values**

# %%
df.capital_loss.describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %% [markdown]
# sns.boxplot(x="salary",y="capital_loss",data=df,hue="salary") ;

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df.groupby("salary").capital_loss.describe()
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %%
df[df.capital_gain>0].groupby("salary").capital_gain.describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [raw]
# **Result :** ..................

# %% [markdown]
# ## hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
sns.boxplot( data=df,x='hours_per_week') ;

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
sns.kdeplot(data=df,x="hours_per_week") ;

# %% [markdown]
# **Check the statistical values**

# %%
df.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
sns.boxplot(data=df,x="salary",y="hours_per_week") ;

# %%
sns.kdeplot(data=df, x="hours_per_week",hue="salary",shade=True)
# Out:
# <AxesSubplot:xlabel='hours_per_week', ylabel='Density'>

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df.groupby("salary").hours_per_week.describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
sns.pairplot(df, hue='salary',corner=True);

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
df.education
# Out:
# 0         Bachelors
# 1         Bachelors
# 2           HS-grad
# 3              11th
# 4         Bachelors
#             ...
# 32556    Assoc-acdm
# 32557       HS-grad
# 32558       HS-grad
# 32559       HS-grad
# 32560       HS-grad
# Name: education, Length: 32537, dtype: object

# %%
df.education_num
# Out:
# 0       13.000
# 1       13.000
# 2        9.000
# 3        7.000
# 4       13.000
#          ...
# 32556   12.000
# 32557    9.000
# 32558    9.000
# 32559    9.000
# 32560    9.000
# Name: education_num, Length: 32537, dtype: float64

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race  gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.education.value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df.education_num.value_counts()
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
df.groupby("education")["education_num"].value_counts(dropna=False)
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# Masters       14.000            1686
#               NaN                 36
# Preschool     1.000               49
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7089
#               NaN                193
# Name: education_num, dtype: int64

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot("education", data=df)
plt.xticks(rotation=45) ;

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot("education_num", data=df) ;
#plt.xticks(rotation=45) ;

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
df.groupby("education").salary.value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# Name: salary, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot(data=df,x="education", hue="salary" )
plt.xticks(rotation=90) ;

# %%
df.groupby("education_num").salary.value_counts()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
#                <=50K      103
# Name: salary, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot(data=df,x="education_num", hue="salary" )
#plt.xticks(rotation=45) ;

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
fig, ax=plt.subplots(figsize=(12,6))
sns.boxplot(data=df,x="salary",y="education_num") ;

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
df.education.value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
df['education'].apply(mapping_education).value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
# By using "mapping_education" def function above, create a new column named "education_summary"
df["education_summary"]=df['education'].apply(mapping_education)

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot(data=df,x="education_summary" ) ;

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %%
df.groupby("education_summary").salary.value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot(data=df,x="education_summary",hue="salary" ) ;

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %%
df.groupby("education_summary").salary.value_counts(normalize=True)
# Out:
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
df_perc=pd.DataFrame(df.groupby("education_summary").salary.value_counts(normalize=True))
df_perc.columns=["percentage"]
df_per=df_perc.unstack(level=0)
df_per
# Out:
#                         percentage
# education_summary high_level_grade low_level_grade medium_level_grade
# salary
# <=50K                        0.515           0.943              0.818
# >50K                         0.485           0.057              0.182

# %%
fig, (ax1, ax2,ax3) = plt.subplots(1, 3,figsize=(20,10))


ax1.pie(df_perc.percentage.high_level_grade.values, labels=df_per.index , autopct='%0.2f%%',normalize=True )
ax1.set_title("high_level_grade ")
ax1.set_ylabel("salary")

ax2.pie(df_perc.percentage.low_level_grade.values, labels=df_per.index ,autopct='%0.2f%%' ,normalize=True )
ax2.set_title("low_level_grade ")
ax2.set_ylabel("salary")

ax3.pie(df_perc.percentage.medium_level_grade.values, labels=df_per.index, autopct='%0.2f%%',normalize=True  )
ax3.set_title("medium_level_grade ")
ax3.set_ylabel("salary")

plt.show()

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %%
df.groupby("salary").education_summary.value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot(data=df,x="salary",hue="education_summary" ) ;

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %%
df.groupby("salary").education_summary.value_counts(normalize=True)
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
df_perc1=pd.DataFrame(df.groupby('salary')['education_summary'].value_counts(normalize=True))
df_perc1.columns=["percentage1"]
df_perc1=df_perc1.unstack(level=0)
df_perc1
# Out:
#                    percentage1
# salary                   <=50K  >50K
# education_summary
# high_level_grade         0.168 0.499
# low_level_grade          0.162 0.031
# medium_level_grade       0.670 0.470

# %%
#colors=color

# %%
df_perc1.plot(kind="pie",
             subplots=True,
             layout=(1,2),
             legend=False,
             autopct="%.2f%%",
             ylabel="education_summary ",
             title=["<=50K",">50K"],
             figsize=(16,8),
             startangle=200);

# %%
#fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(20,10))


#ax1.pie(df_perc1.percentage1[["<=50K"]].values, labels=df_per1.index , autopct='%0.2f%%',normalize=True )
#ax1.set_title("<=50K ")
#ax1.set_ylabel("education_summary")

#ax2.pie(df_perc1.percentage1[[">50K"]].values, labels=df_per1.index ,autopct='%0.2f%%' ,normalize=True )
#ax2.set_title(">50K ")
#ax2.set_ylabel("education_summary")

# %%
#m=df.groupby("salary").education_summary.value_counts(normalize=True)
#m

# %%
#figure_4=m[["<=50K"]]
#figure_4

# %%
#figure_5=m[[">50K"]]
#figure_5

# %%
#fig, (ax1, ax2,) = plt.subplots(1, 2,figsize=(20,10))


#ax1.pie(figure_4.values, labels=figure_4.index , autopct='%0.2f%%',normalize=True )
#ax1.set_title("<=50K ")

#ax2.pie(figure_5.values, labels=figure_5.index , autopct='%0.2f%%' ,normalize=True )
#ax2.set_title(">50K ")



#plt.show()

# %%
#fig, (ax1, ax2,) = plt.subplots(1, 2,figsize=(20,10))


#ax1.pie(figure_4.values, labels=['medium','high','low'] , autopct='%0.2f%%',normalize=True )
#ax1.set_title("<=50K ")
#ax1.set_ylabel("education_summary")

#ax2.pie(figure_5.values, labels=['high','medium','low'] , autopct='%0.2f%%' ,normalize=True )
#ax2.set_title(">50K ")
#ax2.set_ylabel("education_summary")

#plt.show()

# %%
df2=pd.DataFrame(df.groupby('salary')['education_summary'].value_counts(normalize=True))
df2.columns=["percentage2"]
df2=df2.unstack(level=0)
df2
# Out:
#                    percentage2
# salary                   <=50K  >50K
# education_summary
# high_level_grade         0.168 0.499
# low_level_grade          0.162 0.031
# medium_level_grade       0.670 0.470

# %%
df2.plot(kind="pie",
             subplots=True,
             layout=(1,2),
             legend=False,
             autopct="%.2f%%",
             ylabel="percentage ",
             title=["<=50K",">50K"],
             figsize=(16,8),startangle=200);

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
df.marital_status.value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race  gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K
#
#     education_summary
# 0    high_level_grade
# 1    high_level_grade
# 2  medium_level_grade
# 3     low_level_grade
# 4    high_level_grade

# %%
df.relationship.value_counts(dropna=False)
# Out:
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill missing values with "Unknown" in the column of "relationship"

df.relationship.fillna("Unkown",inplace=True)
df.relationship
# Out:
# 0        Not-in-family
# 1              Husband
# 2        Not-in-family
# 3              Husband
# 4                 Wife
#              ...
# 32556             Wife
# 32557          Husband
# 32558        Unmarried
# 32559           Unkown
# 32560             Wife
# Name: relationship, Length: 32537, dtype: object

# %%
df.groupby("relationship").marital_status.value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unkown          Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: marital_status, dtype: int64

# %% [markdown]
# **Assessment :** ........

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot(data=df,x="marital_status" ) 
plt.xticks(rotation=45) ;

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
df.groupby("marital_status").salary.value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot(data=df,x="marital_status",hue="salary" ) 
plt.xticks(rotation=45) ;

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
df.marital_status.apply(mapping_marital_status).value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"
df["marital_status_summary"]=df['marital_status'].apply(mapping_marital_status)
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race  gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K
#
#     education_summary marital_status_summary
# 0    high_level_grade              unmarried
# 1    high_level_grade                married
# 2  medium_level_grade              unmarried
# 3     low_level_grade                married
# 4    high_level_grade                married

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot(data=df,x="marital_status_summary" ) ;

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %%
df.groupby("marital_status_summary").salary.value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.countplot(data=df,x="marital_status_summary",hue="salary" ) ;

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %%
df.groupby("marital_status_summary").salary.value_counts(normalize=True)
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
df3=df.groupby("marital_status_summary").salary.value_counts(normalize=True).to_frame()
df3=df3.unstack(level=0)
df3
# Out:
#                         salary
# marital_status_summary married unmarried
# salary
# <=50K                    0.563     0.935
# >50K                     0.437     0.065

# %%
df3.plot(kind='pie',
            subplots=True,
            layout=(1,2),
            colors=["#ffa3b1","#77d2fc"],
            legend=False,
            autopct='%.2f%%',
            ylabel= "salary",
            title=["married","unmarried"],
            figsize=(14,6));
 
plt.tight_layout()

# %%
#figure_6=df3[["married"]]
#figure_6

# %%
#figure_7=df3[["unmarried"]]
#figure_7

# %%
#fig, (ax1, ax2,) = plt.subplots(1, 2,figsize=(20,10))


#ax1.pie(figure_6.values, labels=figure_6.index , autopct='%0.2f%%',normalize=True )
#ax1.set_title("married ")

#ax2.pie(figure_7.values, labels=figure_7.index , autopct='%0.2f%%' ,normalize=True )
#ax2.set_title("unmarried ")



#plt.show()

# %%
#fig = plt.figure(figsize=(20,10),dpi=98)
#ax = fig.add_subplot(121)
#cts = df.groupby("marital_status_summary").salary.value_counts().married
#ax.pie(cts, labels=cts.index,autopct="%.1f%%")
#ax.set_title("married");
#ax = fig.add_subplot(122)
#cts = df.groupby("marital_status_summary").salary.value_counts().unmarried
#ax.pie(cts,labels=cts.index,autopct="%.1f%%")
#ax.set_title("unmarried");

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %%
df.groupby("salary").marital_status_summary.value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
sns.countplot(data=df,x='salary',hue="marital_status_summary") ;

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %%
df.groupby("salary").marital_status_summary.value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
df4=df.groupby("salary").marital_status_summary.value_counts(normalize=True).to_frame()
df4.rename(columns={'marital_status_summary':'percentage3'},inplace=True)
df4=df4.unstack(level=0)
df4
# Out:
#                        percentage3
# salary                       <=50K  >50K
# marital_status_summary
# married                      0.351 0.859
# unmarried                    0.649 0.141

# %%
df4.plot(kind='pie',
            subplots=True,
            layout=(1,2),
            colors=["#ffa3b1","#77d2fc"],
            legend=False,
            autopct='%.2f%%',
            ylabel= "percentage",
            title=["'<=50K'",">50"],
            figsize=(14,6));
 
plt.tight_layout()

# %%
#df4.rename(columns={"marital_status_summary":""},inplace=True)

# %%
#df4.reset_index()

# %%
fig, (ax1, ax2,) = plt.subplots(1, 2,figsize=(20,10))


ax1.pie(df4.percentage3['<=50K'].values, labels=df4.index, autopct='%0.2f%%',normalize=True )
ax1.set_title("<=50K")
ax1.set_ylabel("percentage")

ax2.pie(df4.percentage3['>50K'].values, labels=df4.index, autopct='%0.2f%%' ,normalize=True )
ax2.set_title(">50K ")
ax2.set_ylabel("percentage");

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** .................

# %% [markdown]
# ## workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(12,6))
sns.countplot(x="workclass",data=df,ax=ax)

plt.xticks(rotation=90) ;

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unkown"

df.replace(to_replace=r'?', value='Unkown',inplace=True)

# %%
df.workclass.sample(10)
# Out:
# 32371    Self-emp-not-inc
# 21444             Private
# 3269               Unkown
# 610               Private
# 16368             Private
# 11804             Private
# 21781             Private
# 2931     Self-emp-not-inc
# 26425             Private
# 17848             Private
# Name: workclass, dtype: object

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
df.groupby("workclass").salary.value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unkown            <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(12,6))
sns.countplot(x="workclass",data=df,hue="salary",ax=ax)

plt.xticks(rotation=90) ;

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
df5=df.groupby(["workclass"])["salary"].value_counts(normalize=True).to_frame()
df5
# Out:
#                          salary
# workclass        salary
# Federal-gov      <=50K    0.614
#                  >50K     0.386
# Local-gov        <=50K    0.705
#                  >50K     0.295
# Never-worked     <=50K    1.000
# Private          <=50K    0.781
#                  >50K     0.219
# Self-emp-inc     >50K     0.557
#                  <=50K    0.443
# Self-emp-not-inc <=50K    0.715
#                  >50K     0.285
# State-gov        <=50K    0.728
#                  >50K     0.272
# Unkown           <=50K    0.896
#                  >50K     0.104
# Without-pay      <=50K    1.000

# %%
df5.rename(columns={"salary":""},inplace=True)

# %%
df5
# Out:
#
# workclass        salary
# Federal-gov      <=50K  0.614
#                  >50K   0.386
# Local-gov        <=50K  0.705
#                  >50K   0.295
# Never-worked     <=50K  1.000
# Private          <=50K  0.781
#                  >50K   0.219
# Self-emp-inc     >50K   0.557
#                  <=50K  0.443
# Self-emp-not-inc <=50K  0.715
#                  >50K   0.285
# State-gov        <=50K  0.728
#                  >50K   0.272
# Unkown           <=50K  0.896
#                  >50K   0.104
# Without-pay      <=50K  1.000

# %%
df5.reset_index(inplace=True)

# %%
df5.rename(columns={'':'percentage'},inplace=True)

# %%
df5
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13            Unkown  <=50K       0.896
# 14            Unkown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %%
fig, ax=plt.subplots(figsize=(12,6))
ax=sns.barplot(x="workclass",y="percentage",hue="salary",data=df5)
plt.xticks(rotation=90)

for i in ax.containers :
    ax.bar_label(i,fmt='%.2f')

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
df.groupby("salary").workclass.value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unkown               1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unkown                191
# Name: workclass, dtype: int64

# %%
sns.countplot(x="salary",hue="workclass",data=df) ;

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
df.groupby("salary").workclass.value_counts(normalize=True)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unkown             0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unkown             0.024
# Name: workclass, dtype: float64

# %%
df6=df.groupby(["salary"])["workclass"].value_counts(normalize=True).to_frame()
df6
# Out:
#                          workclass
# salary workclass
# <=50K  Private               0.717
#        Self-emp-not-inc      0.074
#        Unkown                0.067
#        Local-gov             0.060
#        State-gov             0.038
#        Federal-gov           0.024
#        Self-emp-inc          0.020
#        Without-pay           0.001
#        Never-worked          0.000
# >50K   Private               0.633
#        Self-emp-not-inc      0.092
#        Self-emp-inc          0.079
#        Local-gov             0.079
#        Federal-gov           0.047
#        State-gov             0.045
#        Unkown                0.024

# %%
df6.rename(columns={"workclass":""},inplace=True)

# %%
df6
# Out:
#
# salary workclass
# <=50K  Private          0.717
#        Self-emp-not-inc 0.074
#        Unkown           0.067
#        Local-gov        0.060
#        State-gov        0.038
#        Federal-gov      0.024
#        Self-emp-inc     0.020
#        Without-pay      0.001
#        Never-worked     0.000
# >50K   Private          0.633
#        Self-emp-not-inc 0.092
#        Self-emp-inc     0.079
#        Local-gov        0.079
#        Federal-gov      0.047
#        State-gov        0.045
#        Unkown           0.024

# %%
df6.rename(columns={'':'percentage'},inplace=True)

# %%
df6.reset_index(inplace=True)

# %%
df6
# Out:
#    salary         workclass  percentage
# 0   <=50K           Private       0.717
# 1   <=50K  Self-emp-not-inc       0.074
# 2   <=50K            Unkown       0.067
# 3   <=50K         Local-gov       0.060
# 4   <=50K         State-gov       0.038
# 5   <=50K       Federal-gov       0.024
# 6   <=50K      Self-emp-inc       0.020
# 7   <=50K       Without-pay       0.001
# 8   <=50K      Never-worked       0.000
# 9    >50K           Private       0.633
# 10   >50K  Self-emp-not-inc       0.092
# 11   >50K      Self-emp-inc       0.079
# 12   >50K         Local-gov       0.079
# 13   >50K       Federal-gov       0.047
# 14   >50K         State-gov       0.045
# 15   >50K            Unkown       0.024

# %%
fig, ax=plt.subplots(figsize=(15,8))
hue_order = ['Federal-gov', 'Local-gov', 'Never-worked','Private','Self-emp-inc','Self-emp-not-inc','State-gov','Unkown	','Without-pay']
sns.barplot(x="salary",y="percentage",hue="workclass",data=df6,hue_order=hue_order) 
for i in ax.containers :
    ax.bar_label(i,fmt='%.3f',fontsize=10)  ;

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ..................

# %% [markdown]
# ## occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unkown               1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
sns.countplot(x="occupation",data=df)
plt.xticks(rotation=90) ;

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
df.groupby("occupation").salary.value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# Unkown             <=50K     1652
#                    >50K       191
# Name: salary, dtype: int64

# %%
sns.countplot(x="occupation",hue="salary",data=df) 
plt.xticks(rotation=90);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %%
df.groupby("occupation").salary.value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
#                    >50K     0.200
# Unkown             <=50K    0.896
#                    >50K     0.104
# Name: salary, dtype: float64

# %%
df7=df.groupby("occupation").salary.value_counts(normalize=True).to_frame()
df7
# Out:
#                           salary
# occupation        salary
# Adm-clerical      <=50K    0.865
#                   >50K     0.135
# Armed-Forces      <=50K    0.889
#                   >50K     0.111
# Craft-repair      <=50K    0.773
#                   >50K     0.227
# Exec-managerial   <=50K    0.516
#                   >50K     0.484
# Farming-fishing   <=50K    0.884
#                   >50K     0.116
# Handlers-cleaners <=50K    0.937
#                   >50K     0.063
# Machine-op-inspct <=50K    0.875
#                   >50K     0.124
# Other-service     <=50K    0.958
#                   >50K     0.042
# Priv-house-serv   <=50K    0.993
#                   >50K     0.007
# Prof-specialty    <=50K    0.551
#                   >50K     0.449
# Protective-serv   <=50K    0.675
#                   >50K     0.325
# Sales             <=50K    0.731
#                   >50K     0.269
# Tech-support      <=50K    0.695
#                   >50K     0.305
# Transport-moving  <=50K    0.800
#                   >50K     0.200
# Unkown            <=50K    0.896
#                   >50K     0.104

# %%
df7.rename(columns={'salary':''},inplace=True)

# %%
df7
# Out:
#
# occupation        salary
# Adm-clerical      <=50K  0.865
#                   >50K   0.135
# Armed-Forces      <=50K  0.889
#                   >50K   0.111
# Craft-repair      <=50K  0.773
#                   >50K   0.227
# Exec-managerial   <=50K  0.516
#                   >50K   0.484
# Farming-fishing   <=50K  0.884
#                   >50K   0.116
# Handlers-cleaners <=50K  0.937
#                   >50K   0.063
# Machine-op-inspct <=50K  0.875
#                   >50K   0.124
# Other-service     <=50K  0.958
#                   >50K   0.042
# Priv-house-serv   <=50K  0.993
#                   >50K   0.007
# Prof-specialty    <=50K  0.551
#                   >50K   0.449
# Protective-serv   <=50K  0.675
#                   >50K   0.325
# Sales             <=50K  0.731
#                   >50K   0.269
# Tech-support      <=50K  0.695
#                   >50K   0.305
# Transport-moving  <=50K  0.800
#                   >50K   0.200
# Unkown            <=50K  0.896
#                   >50K   0.104

# %%
df7.reset_index(inplace=True)

# %%
df7.rename(columns={'':'percentage'},inplace=True)

# %%
df7
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# 22              Sales  <=50K       0.731
# 23              Sales   >50K       0.269
# 24       Tech-support  <=50K       0.695
# 25       Tech-support   >50K       0.305
# 26   Transport-moving  <=50K       0.800
# 27   Transport-moving   >50K       0.200
# 28             Unkown  <=50K       0.896
# 29             Unkown   >50K       0.104

# %%
fig, ax=plt.subplots(figsize=(15,8))
sns.barplot(x="occupation",y="percentage",hue="salary",data=df7)
plt.xticks(rotation=90)
for i in ax.containers :
    ax.bar_label(i,fmt='%.2f')

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
df.groupby("salary").occupation.value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unkown               1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unkown                191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: occupation, dtype: int64

# %%
sns.countplot(x="salary",hue="occupation",data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %%
df.groupby("salary").occupation.value_counts(normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unkown              0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unkown              0.024
#         Other-service       0.017
#         Farming-fishing     0.015
#         Handlers-cleaners   0.011
#         Armed-Forces        0.000
#         Priv-house-serv     0.000
# Name: occupation, dtype: float64

# %%
df8=df.groupby("salary").occupation.value_counts(normalize=True).to_frame()
df8
# Out:
#                           occupation
# salary occupation
# <=50K  Adm-clerical            0.132
#        Craft-repair            0.128
#        Other-service           0.128
#        Sales                   0.108
#        Prof-specialty          0.092
#        Exec-managerial         0.085
#        Machine-op-inspct       0.071
#        Unkown                  0.067
#        Handlers-cleaners       0.052
#        Transport-moving        0.052
#        Farming-fishing         0.036
#        Tech-support            0.026
#        Protective-serv         0.018
#        Priv-house-serv         0.006
#        Armed-Forces            0.000
# >50K   Exec-managerial         0.251
#        Prof-specialty          0.237
#        Sales                   0.125
#        Craft-repair            0.119
#        Adm-clerical            0.065
#        Transport-moving        0.041
#        Tech-support            0.036
#        Machine-op-inspct       0.032
#        Protective-serv         0.027
#        Unkown                  0.024
#        Other-service           0.017
#        Farming-fishing         0.015
#        Handlers-cleaners       0.011
#        Armed-Forces            0.000
#        Priv-house-serv         0.000

# %%
df8.rename(columns={'occupation':''},inplace=True)

# %%
df8.rename(columns={'':'percentage'},inplace=True)

# %%
df8.reset_index(inplace=True)

# %%
df8
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 1   <=50K       Craft-repair       0.128
# 2   <=50K      Other-service       0.128
# 3   <=50K              Sales       0.108
# 4   <=50K     Prof-specialty       0.092
# 5   <=50K    Exec-managerial       0.085
# 6   <=50K  Machine-op-inspct       0.071
# 7   <=50K             Unkown       0.067
# 8   <=50K  Handlers-cleaners       0.052
# 9   <=50K   Transport-moving       0.052
# 10  <=50K    Farming-fishing       0.036
# 11  <=50K       Tech-support       0.026
# 12  <=50K    Protective-serv       0.018
# 13  <=50K    Priv-house-serv       0.006
# 14  <=50K       Armed-Forces       0.000
# 15   >50K    Exec-managerial       0.251
# 16   >50K     Prof-specialty       0.237
# 17   >50K              Sales       0.125
# 18   >50K       Craft-repair       0.119
# 19   >50K       Adm-clerical       0.065
# 20   >50K   Transport-moving       0.041
# 21   >50K       Tech-support       0.036
# 22   >50K  Machine-op-inspct       0.032
# 23   >50K    Protective-serv       0.027
# 24   >50K             Unkown       0.024
# 25   >50K      Other-service       0.017
# 26   >50K    Farming-fishing       0.015
# 27   >50K  Handlers-cleaners       0.011
# 28   >50K       Armed-Forces       0.000
# 29   >50K    Priv-house-serv       0.000

# %%
fig, ax=plt.subplots(figsize=(15,8))
hue_order=['Adm-clerical','Armed-Forces','Craft-repair','Exec-managerial','Farming-fishing','Handlers-cleaners','Machine-op-inspct',
           'Other-service','Priv-house-serv',
           'Prof-specialty','Protective-serv','Sales','Tech-support','Transport-moving','Unkown']
sns.barplot(x="salary",y="percentage",hue="occupation",hue_order=hue_order,data=df8)
plt.xticks(rotation=90)
for i in ax.containers :
    ax.bar_label(i,fmt='%.3f')

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ................

# %% [markdown]
# ## race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df.race.value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
sns.countplot(x="race",data=df) 
plt.xticks(rotation=45);

# %%
df.groupby("race").salary.value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
sns.countplot(x="race",hue="salary",data=df)
plt.xticks(rotation=45) ;

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %%
df.groupby("race").salary.value_counts(normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
df_race=df.groupby("race").salary.value_counts(normalize=True).to_frame()
df_race.columns=["salary"]
df_race=df_race.unstack(level=0)
df_race
# Out:
#                    salary
# race   Amer-Indian-Eskimo Asian-Pac-Islander Black Other White
# salary
# <=50K               0.884              0.734 0.876 0.908 0.744
# >50K                0.116              0.266 0.124 0.092 0.256

# %%
plt.figure(figsize=(100,120))
df_race.plot(kind="pie",subplots=True,legend=False,layout=(2,3),autopct="%.2f%%", 
            ylabel="salary",
            title=["Amer-Indian-Eskimo","Asian-Pac-Islander","Black","Other","White"],
            figsize=(16,8));

plt.tight_layout()

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
df.groupby("salary").race.value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
sns.countplot(x="salary",hue="race",data=df);

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %%
df.groupby("salary").race.value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
df9=df.groupby("salary").race.value_counts(normalize=True).to_frame()
df9
# Out:
#                            race
# salary race
# <=50K  White              0.837
#        Black              0.111
#        Asian-Pac-Islander 0.031
#        Amer-Indian-Eskimo 0.011
#        Other              0.010
# >50K   White              0.908
#        Black              0.049
#        Asian-Pac-Islander 0.035
#        Amer-Indian-Eskimo 0.005
#        Other              0.003

# %%
df9.rename(columns={'race':''},inplace=True)

# %%
df9.rename(columns={'':'percentage'},inplace=True)

# %%
df9.reset_index(inplace=True)

# %%
df9.sort_values(by=['salary','race'],inplace=True)

# %%
df9
# Out:
#   salary                race  percentage
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 2  <=50K  Asian-Pac-Islander       0.031
# 1  <=50K               Black       0.111
# 4  <=50K               Other       0.010
# 0  <=50K               White       0.837
# 8   >50K  Amer-Indian-Eskimo       0.005
# 7   >50K  Asian-Pac-Islander       0.035
# 6   >50K               Black       0.049
# 9   >50K               Other       0.003
# 5   >50K               White       0.908

# %%
fig, ax=plt.subplots(figsize=(15,6))
sns.barplot(x="salary",y="percentage",hue="race",data=df9)
for i in ax.containers :
    ax.bar_label(i,fmt='%.2f')

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ................

# %% [markdown]
# ## gender

# %% [markdown]
# **Check the count of person in each gender and visualize it with countplot**

# %%
df.gender.value_counts()
# Out:
# Male      21775
# Female    10762
# Name: gender, dtype: int64

# %%
sns.countplot(x="gender",data=df) ;

# %% [markdown]
# **Check the count of person in each "salary" levels by gender and visualize it with countplot**

# %%
df.groupby("gender").salary.value_counts()
# Out:
# gender  salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
sns.countplot(x="gender",hue="salary",data=df) ;

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot**

# %%
df.groupby("gender").salary.value_counts(normalize=True)
# Out:
# gender  salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
df10=df.groupby("gender").salary.value_counts(normalize=True).to_frame()
df10
# Out:
#                salary
# gender salary
# Female <=50K    0.890
#        >50K     0.110
# Male   <=50K    0.694
#        >50K     0.306

# %%
df10.columns=["salary"]
df10=df10.unstack(level=0)
df10
# Out:
#        salary
# gender Female  Male
# salary
# <=50K   0.890 0.694
# >50K    0.110 0.306

# %%
df10.plot(kind="pie",subplots=True,legend=False,layout=(1,5),autopct="%.2f%%", 
            ylabel="salary",
            title=["Female","Male"],
            figsize=(51,8));

# %% [markdown]
# **Check the count of person in each gender by "salary" levels and visualize it with countplot**

# %%
df.groupby("salary").gender.value_counts()
# Out:
# salary  gender
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: gender, dtype: int64

# %%
sns.countplot(x="salary",hue="gender",data=df) ;

# %% [markdown]
# **Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot**

# %%
df.groupby("salary").gender.value_counts(normalize=True)
# Out:
# salary  gender
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: gender, dtype: float64

# %%
df11=df.groupby("salary").gender.value_counts(normalize=True).to_frame()
df11.columns=["gender"]
df11=df11.unstack(level=0)
df11
# Out:
#        gender
# salary  <=50K  >50K
# gender
# Female  0.388 0.150
# Male    0.612 0.850

# %%
df11.plot(kind="pie",subplots=True,legend=False,layout=(1,5),autopct="%.2f%%", 
            ylabel="salary",
            title=["<=50K",">50K"],
            figsize=(51,8));

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ..............

# %% [markdown]
# ## native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df.native_country.value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# Unkown                          582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64

# %%
sns.countplot(x="native_country",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
df.native_country.apply(mapping_native_country).value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"

df["native_country_summary"]=df['native_country'].apply(mapping_native_country)

# %%
df.native_country_summary
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %%
df.native_country_summary.value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country_summary, dtype: int64

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %%
sns.countplot(x="native_country_summary",data=df);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %%
df.groupby("native_country_summary").salary.value_counts(normalize=True)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
df12=df.groupby("native_country_summary").salary.value_counts(normalize=True).to_frame()
df12.columns=["native_country_summary"]
df12=df12.unstack(level=0)
df12
# Out:
#                        native_country_summary
# native_country_summary                 Others    US
# salary
# <=50K                                   0.802 0.754
# >50K                                    0.198 0.246

# %%
df12.plot(kind="pie",subplots=True,legend=False,layout=(1,5),autopct="%.2f%%", 
            ylabel="salary",
            title=["Others","US"],
            figsize=(51,8));

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %%
df.groupby("salary").native_country_summary.value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
sns.countplot(x="salary",hue="native_country_summary",data=df);

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %%
df.groupby("salary").native_country_summary.value_counts(normalize=True)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
df13=df.groupby("salary").native_country_summary.value_counts(normalize=True).to_frame()
df13.columns=["salary"]
df13=df13.unstack(level=0)
df13
# Out:
#                        salary
# salary                  <=50K  >50K
# native_country_summary
# Others                  0.110 0.085
# US                      0.890 0.915

# %%
df13.plot(kind="pie",subplots=True,legend=False,layout=(1,5),autopct="%.2f%%", 
            ylabel="native_country_summary",
            title=["<=50K",">50K"],
            figsize=(51,8));

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** .................

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
df15=df.groupby(["salary","gender"]).age.mean().to_frame()

df15
# Out:
#                  age
# salary gender
# <=50K  Female 36.217
#        Male   37.149
# >50K   Female 42.126
#        Male   44.627

# %%
df15['age'].index
# Out:
# MultiIndex([('<=50K', 'Female'),
#             ('<=50K',   'Male'),
#             ( '>50K', 'Female'),
#             ( '>50K',   'Male')],
#            names=['salary', 'gender'])

# %%
df15['age'].values
# Out:
# array([36.21746843, 37.14872643, 42.12553011, 44.62717718])

# %%
fig, ax=plt.subplots(figsize=(15,6))
df15['age'].plot(kind='bar')
for i in ax.containers :
    ax.bar_label(i,fmt='%.2f');

# %%
#sns.barplot(x=['age'].index,data=df15)

# %%
df14=df.groupby(["salary","gender"]).age.mean().to_frame()
df14.reset_index(inplace=True)
df14.sort_values(by=['salary','gender'])
# Out:
#   salary  gender    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %%
fig, ax=plt.subplots(figsize=(15,6))
sns.barplot(x="salary",y="age",hue="gender",data=df14)
for i in ax.containers :
    ax.bar_label(i,fmt='%.2f')
plt.xticks(rotation=0);
# Out:
# (array([0, 1]), [Text(0, 0, '<=50K'), Text(1, 0, '>50K')])

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
df.sample(5)
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 24811   47           Private  144844       HS-grad          9.000
# 23037   20           Private   24967       HS-grad          9.000
# 25648   32  Self-emp-not-inc   84119       HS-grad          9.000
# 23667   23           Private  143062       HS-grad          9.000
# 813     22           Private  137510  Some-college         10.000
#
#            marital_status       occupation relationship   race gender  \
# 24811  Married-civ-spouse     Craft-repair      Husband  White   Male
# 23037       Never-married  Farming-fishing       Unkown  White   Male
# 25648  Married-civ-spouse     Craft-repair      Husband  White   Male
# 23667       Never-married            Sales       Unkown  White   Male
# 813         Never-married     Adm-clerical       Unkown  White   Male
#
#        capital_gain  capital_loss  hours_per_week native_country salary  \
# 24811             0             0              40  United-States  <=50K
# 23037             0             0              47  United-States  <=50K
# 25648             0             0              45  United-States  <=50K
# 23667             0             0              40  United-States  <=50K
# 813               0             0              40  United-States  <=50K
#
#         education_summary marital_status_summary native_country_summary
# 24811  medium_level_grade                married                     US
# 23037  medium_level_grade              unmarried                     US
# 25648  medium_level_grade                married                     US
# 23667  medium_level_grade              unmarried                     US
# 813    medium_level_grade              unmarried                     US

# %%
df16 = df.loc[ (df["salary"] == ">50K") & (df["native_country"]=="United-States")]["workclass"].value_counts(normalize=True)*100
df16
# Out:
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unkown              2.455
# Name: workclass, dtype: float64

# %%
fig, ax=plt.subplots(figsize=(15,6))
df16.plot(kind='bar')
plt.xticks(rotation=45)
for i in ax.containers :
    ax.bar_label(i,fmt='%.2f');

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
df.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unkown               1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df.occupation.loc[df.workclass=='Private'].loc[df.salary=='>50K' ].loc[  df.native_country_summary=='US'].value_counts()

# %%
df17=df.occupation.loc[df.workclass=='Private' ].loc[df.salary=='>50K' ].loc[  df.native_country_summary=='US'].value_counts(normalize=True)*100

# %%
df17
# Out:
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
fig, ax=plt.subplots(figsize=(15,6))
df17.plot(kind='bar')
plt.xticks(rotation=90)
for i in ax.containers :
    ax.bar_label(i,fmt='%.2f');

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race  gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K
#
#     education_summary marital_status_summary native_country_summary
# 0    high_level_grade              unmarried                     US
# 1    high_level_grade                married                     US
# 2  medium_level_grade              unmarried                     US
# 3     low_level_grade                married                     US
# 4    high_level_grade                married                 Others

# %%
df18=df.education.loc[df.race=='Asian-Pac-Islander'].loc[df.salary=='>50K' ].value_counts(normalize=True)*100

# %%
fig, ax=plt.subplots(figsize=(15,6))
df18.plot(kind='bar')
plt.xticks(rotation=90)
for i in ax.containers :
    ax.bar_label(i,fmt='%.2f');

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race  gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K
#
#     education_summary marital_status_summary native_country_summary
# 0    high_level_grade              unmarried                     US
# 1    high_level_grade                married                     US
# 2  medium_level_grade              unmarried                     US
# 3     low_level_grade                married                     US
# 4    high_level_grade                married                 Others

# %%
df19=df.occupation.loc[df.race=='Asian-Pac-Islander' ].loc[df.salary=='>50K' ].loc[  df.education=='Bachelors'].value_counts(normalize=True)*100

# %%
df19
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
fig, ax=plt.subplots(figsize=(15,6))
df19.plot(kind='bar')
plt.xticks(rotation=90)
for i in ax.containers :
    ax.bar_label(i,fmt='%.2f');

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
sns.catplot(x="education_summary", 
            y="hours_per_week", 
            kind="bar", 
            data= df, 
            estimator=np.mean,
            ci=None,
            height=8, aspect=1,
            hue="gender",
            col="marital_status_summary",
            row="native_country_summary")

plt.tight_layout()

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   gender                  32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
#  14  salary                  32537 non-null  object
#  15  education_summary       32537 non-null  object
#  16  marital_status_summary  32537 non-null  object
#  17  native_country_summary  32537 non-null  object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 5.7+ MB

# %%
# Drop the columns of "education", "education_num", "relationship", "marital_status", "native_country" permanently
df.drop(columns={"education", "education_num", "relationship", "marital_status", "native_country"},inplace=True)

# %%
df
# Out:
#        age         workclass  fnlwgt         occupation   race  gender  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 0              2174             0              40  <=50K    high_level_grade
# 1                 0             0              13  <=50K    high_level_grade
# 2                 0             0              40  <=50K  medium_level_grade
# 3                 0             0              40  <=50K     low_level_grade
# 4                 0             0              40  <=50K    high_level_grade
# ...             ...           ...             ...    ...                 ...
# 32556             0             0              38  <=50K  medium_level_grade
# 32557             0             0              40   >50K  medium_level_grade
# 32558             0             0              40  <=50K  medium_level_grade
# 32559             0             0              20  <=50K  medium_level_grade
# 32560         15024             0              40   >50K  medium_level_grade
#
#       marital_status_summary native_country_summary
# 0                  unmarried                     US
# 1                    married                     US
# 2                  unmarried                     US
# 3                    married                     US
# 4                    married                 Others
# ...                      ...                    ...
# 32556                married                     US
# 32557                married                     US
# 32558              unmarried                     US
# 32559              unmarried                     US
# 32560                married                     US
#
# [32537 rows x 13 columns]

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   occupation              32537 non-null  object
#  4   race                    32537 non-null  object
#  5   gender                  32537 non-null  object
#  6   capital_gain            32537 non-null  int64
#  7   capital_loss            32537 non-null  int64
#  8   hours_per_week          32537 non-null  int64
#  9   salary                  32537 non-null  object
#  10  education_summary       32537 non-null  object
#  11  marital_status_summary  32537 non-null  object
#  12  native_country_summary  32537 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 4.5+ MB

# %%
df.isna().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unkown               1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unkown               1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df.loc[ (df["workclass"]=='Unknown') | (df["workclass"]=='Never-worked') 
                                      ]["workclass"].value_counts(dropna=False)
# Out:
# Unkown    1836
# Name: workclass, dtype: int64

# %%
# Replace "Unknown" values with NaN using numpy library

# Your Code is Here

df["workclass"].replace(to_replace="Unknown", value=np.nan, inplace=True)
df["occupation"].replace(to_replace="Unknown", value=np.nan, inplace=True)

# %%
# Your Code is Here

df[ df == 'Unknown'].count()

# %%
df.dropna(inplace=True)

# %%
df[ df == 'Unknown'].count()

# %%
# Your Code is Here

df.info()

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# Your Code is Here

sns.boxplot(data=df, orient='v');
# Out:
# <AxesSubplot:>

# %%
df.plot.box(subplots=True, layout=(2,3), vert=True)

# %%
df_num = df.select_dtypes(include=np.number)

fig, ax = plt.subplots(nrows=2, ncols=3,figsize=(20,10))

x = 0
for i in range(2):
    for j in range(3):   
        if x<5:
            g = sns.boxplot(data=df_num.iloc[:,x], ax=ax[i][j],orient="h")
            g.set(xlabel = z)
            g.set_yticklabels("")
            x+=1

# %%
df_num = df.select_dtypes(include=np.number)
fig, ax = plt.subplots(nrows=2, ncols=3,figsize=(20,10))
i = j = 0
for z in df_num.columns:
    g = sns.boxplot(data=df_num[z], ax=ax[i][j],orient="h")
    g.set(xlabel = z)
    g.set_yticklabels("")
    j += 1
    if j>2:
        i += 1; j = 0

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

df_num = df.select_dtypes(include=np.number)

fig, ax = plt.subplots(nrows=5, ncols=2,figsize=(10,15))
i = j = 0

for z in df_num.columns:
    g = sns.boxplot(data=df_num[z], ax=ax[i][j],orient="h")
    g.set(xlabel = z)
    g.set_yticklabels("")
    j+=1
    sns.histplot(data=df_num[z], ax=ax[i][j])
    j=0 
    i += 1
    
plt.tight_layout()

# %%
df.describe().T

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
# Your Code is Here

fig, ax = plt.subplots(1,2,figsize=(12,6))

sns.boxplot(data=df["age"], ax=ax[0])
sns.histplot(data=df["age"], ax=ax[1]) 

plt.tight_layout()

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

q1 = df["age"].quantile(0.25)
q3 = df["age"].quantile(0.75)
iqr = q3 - q1

q1,q3,iqr

# %%
np.percentile(df["age"],25), np.percentile(df["age"],75), stats.iqr(df["age"])

# %%
# Find lower and upper limit using IQR

# Your Code is Here

lower_lim = q1 - (1.5*iqr)
upper_lim = q3 + (1.5*iqr)
lower_lim, upper_lim

# %%
# Your Code is Here

df.loc[ df["age"]>upper_lim ]["age"].value_counts()

# %%
# Define the observations whose age is greater than upper limit and sort these observations by age in descending order

# Your Code is Here

df.loc[ df["age"]>upper_lim ].sort_values(by="age",ascending=False)

# %% [markdown]
# ### hours_per_week

# %%
# Your Code is Here

fig, ax = plt.subplots(1,2,figsize=(12,6))

sns.boxplot(data=df["hours_per_week"], ax=ax[0])
sns.histplot(data=df["hours_per_week"], ax=ax[1], bins=10) 

plt.tight_layout()

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

q1 = df["hours_per_week"].quantile(0.25)
q3 = df["hours_per_week"].quantile(0.75)
iqr = q3 - q1

q1,q3,iqr

# %%
# Find the lower and upper limit using IQR

# Your Code is Here

lower_lim = q1 - (1.5*iqr)
upper_lim = q3 + (1.5*iqr)
lower_lim, upper_lim

# %%
# Your Code is Here

df[(df["hours_per_week"]>upper_lim)]["hours_per_week"].value_counts().sort_index(ascending=False)

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# Your Code is Here

df[(df["hours_per_week"]>upper_lim)].sort_values(by="hours_per_week",ascending=False)

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# Your Code is Here

df[(df["hours_per_week"]>upper_lim)].sort_values(by="hours_per_week",ascending=False)

# %%
# Your Code is Here

df[(df["hours_per_week"] < lower_lim)]["hours_per_week"].value_counts().sort_index()

# %%
df[(df["hours_per_week"] < lower_lim)].sort_values(by="hours_per_week", ascending=False)

# %%
# Your Code is Here

df.loc[ (df["hours_per_week"]<lower_lim)].groupby("salary")["hours_per_week"].describe()

# %%
# Your Code is Here

df[(df["hours_per_week"] < lower_lim)].groupby("salary")["age"].describe()

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
# Create a condition according to your domain knowledge on age stated above and 
# sort the observations meeting this condition by age in ascending order

# Your Code is Here

df.loc[ df["age" ]>80 ]

# %%
# Find the shape of the dataframe created by the condition defined above for age 

# Your Code is Here

df.loc[ df["age" ]>80 ].shape

# %%
# Assign the indices of the rows defined in accordance with condition above for age

# Your Code is Here

df.loc[ df["age" ]>80 ].index

# %%
# Drop these indices defined above for age

# Your Code is Here

df.drop( index=df[df["age"]>80].index,inplace=True )

# %%
# Create a condition according to your domain knowledge on hours per week stated above and 
# sort the observations meeting this condition by hours per week in descending order

# Your Code is Here

df[(df["hours_per_week"]>70) | (df["hours_per_week"]<7)].sort_values(by='hours_per_week',ascending=False)

# %%
# Find the shape of the dataframe created by the condition defined above for hours per week 

# Your Code is Here

df[(df["hours_per_week"]>70) | (df["hours_per_week"]<7)].sort_values(by='hours_per_week',ascending=False).shape

# %%
# Assign the indices of the rows defined in accordance with condition above for hours per week

# Your Code is Here

df[(df["hours_per_week"]>70) | (df["hours_per_week"]<7)].sort_values(by='hours_per_week',ascending=False).index

# %%
# Assign the indices of the rows defined in accordance with condition above for hours per week

# Your Code is Here

df[(df["hours_per_week"]>70) | (df["hours_per_week"]<7)].sort_values(by='hours_per_week',ascending=False).index

# %%
# Drop these indices defined above for hours per week

# Your Code is Here

df.drop(index=df[(df["hours_per_week"]>70) | (df["hours_per_week"]<7)].index, inplace=True)

# %%
# Create a condition according to your domain knowledge on both age and hours per week stated above 

# Your Code is Here

df.loc[ (df['age']>60) & (df['hours_per_week']>60) ]

# %%
# Assign the indices of the rows defined in accordance with condition above for both age and hours per week

# Your Code is Here

df.loc[ (df['age']>60) & (df['hours_per_week']>60) ].index

# %%
# Drop these indices defined above for both age and hours per week

# Your Code is Here

df.drop(index=df.loc[ (df['age']>60) & (df['hours_per_week']>60) ].index, inplace=True)

# %%
# What is new shape of dataframe now

# Your Code is Here

df.shape

# %%
df.info()

# %%
# Reset the indices and take the head of DataFrame now

# Your Code is Here

df.reset_index(drop=True, inplace=True)
df.head()

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %%
# Your Code is Here

df['salary'] = df.salary.map({'<=50K': 0, '>50K': 1})
df['salary']

# %%
df['salary'].value_counts()

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
pd.get_dummies(df, drop_first=True)

# %%
df.shape

# %%
pd.get_dummies(df, drop_first=True).shape

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
pd.get_dummies(df, drop_first=True).corr()

# %%
# Your Code is Here

plt.figure(figsize=(14,20))

sns.heatmap(pd.get_dummies(df, drop_first=True).corr(), annot=True, cmap='YlGnBu', annot_kws={'fontsize':8})

# %%
# Your Code is Here

df_sal_corr = pd.get_dummies(df, drop_first=True).corr()[['salary']].sort_values(by='salary', ascending=False)[1:]
df_sal_corr

# %%
# Your Code is Here

plt.figure(figsize=(3,12))

sns.heatmap(df_sal_corr, annot=True, cmap='YlGnBu')

# %%
# Your Code is Here

plt.figure(figsize=(5,10))

sns.barplot(y=df_sal_corr.index, x=df_sal_corr.salary, color='royalblue')

# %%
df_sal_corr[::-1].plot.barh(figsize=(5,13), legend=False)

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
